# %% [markdown]
# # IPL 2022 Project
# The Indian Premier League (IPL) is a professional T20 cricket league in India featuring franchise teams representing different cities.
#
# In this project, you will analyze IPL 2022 match-level data using Python and the libraries you have learned throughout this course.
#
# You will use:
#
# * Python
# * NumPy
# * Pandas
# * Matplotlib
# * Seaborn
# * OOP concepts where appropriate
#
# The objective is not simply to find answers, but to explore the dataset, identify patterns, visualize results, and explain your findings.
#
# Important: For every major result, try to explain what the result tells us.
#
# **column names: Variable Type**
# * date : string
# * venue : string
# * stage : string
# * team1 : string
# * team2 : string
# * toss_winner : string
# * toss_decision : string
# * first_ings_score : integer
# * second_ings_score : integer
# * match_winner : string
# * won_by : string
# * margin : integer
# * player_of_the_match : string
# * top_scorer : string
# * highscore : integer
# * best_bowling : string
# * best_bowling_fgure : string
# * gure : string

# %% [markdown]
# # Loading the Libraries and Dataset

# %% [markdown]
# # Understanding the Dataset

# %% [markdown]
# * Q1. Display the first 5 rows.
# * Q2. Display the last 5 rows.
# * Q3. Find the number of rows and columns.
# * Q4. Display all column names.
# * Q5. Display basic information about the dataset.
# * Q6. Generate descriptive statistics for numerical columns.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# * Q7. Find the number of missing values in each column.
# * Q8. Find the total number of duplicate rows.
# * Q9. Check the data types of all columns.
# * Q10. Convert the date column to the appropriate datetime format.
# * Q11. Check whether the conversion was successful.

# %% [markdown]
# ### Now, Here comes some Basic Questions

# %% [markdown]
# * Which team won the most matches?

# %% [markdown]
# * Toss Decision Trends

# %% [markdown]
# * Toss Winner vs Match Winner

# %% [markdown]
# * How do teams win? (Runs vs Wickets)

# %% [markdown]
# # Key Player Performances

# %% [markdown]
# * 1 Most "Player of the Match" Awards

# %% [markdown]
# * Top Scorers

# %% [markdown]
# * 10 Best Bowling Figures

# %% [markdown]
# # Venue Analysis

# %% [markdown]
# * Most Matches Played by Venue

# %% [markdown]
# # Custom Questions & Insights

# %% [markdown]
# * Q1: Who won the highest margin by runs?

# %% [markdown]
# * Q2: Which player had the highest individual score?

# %% [markdown]
# * Q3: Which bowler had the best bowling figures?

# %% [markdown]
# # Visualization Section 📊
#
# Create at least 5 visualizations.

# %% [markdown]
# # Good Work
